# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
#Two strain case
#large frequency
ax1=plt.axes((0.0,0.7,0.3,0.25))

#frame
#ax1.hlines(0,0,1,colors='black',lw=3)
ax1.annotate('',xy=(1,0),xytext=(0,0),arrowprops=dict(arrowstyle='->'))
#ax.fill_between([0.3,0.7],0.02,0,color='lightgray')
ax1.fill_between([0,1],0.02,0,color='green',alpha=0.3)
#ax1.fill_between([0.3,1],0.02,0,color='red',alpha=0.5)
#ax.annotate('Fail',xy=(0.45,0.005))
ax1.annotate(r'$0$',xy=(0,-0.02))
ax1.annotate(r'$1$',xy=(0.95,-0.02))
#ax1.annotate('Mutant\nfrequency',xy=(1.05,-0.005))
ax1.annotate('a',xy=(-0.0,0.95),weight='bold',xycoords='axes fraction')
ax1.annotate(' Two-strain',xy=(0.05,0.95),xycoords='axes fraction')

ax1.set_ylim(ymin=-0.05,ymax=0.05)

tgt=0.9
ini1=0.2
h1=0.01
ini2=0.5
h2=0.01
ini3=0.8
h3=0.01
#ax1.scatter(tgt,0.015,c='black',marker='s') #target
ax1.vlines(tgt,0,0.02,colors='black',ls=':',label='Target') #target
#ax1.annotate('Target',xy=(tgt,0.015),xytext=(tgt-0.1,0.035),arrowprops=dict(arrowstyle='->'))
ax1.scatter(ini1,h1,c='black',marker='o',label='Initial') #initial 1
#ax1.annotate('Initial',xy=(ini1,0.015),xytext=(ini1-0.05,0.03),arrowprops=dict(arrowstyle='->'))
ax1.scatter(ini2,h2,c='black',marker='o') #initial 2
#ax1.annotate('Initial',xy=(ini2,0.015),xytext=(ini2-0.05,0.03),arrowprops=dict(arrowstyle='->'))
ax1.scatter(ini3,h3,c='black',marker='o') #initial 2
#ax1.annotate('Initial',xy=(ini3,0.015),xytext=(ini3-0.05,0.03),arrowprops=dict(arrowstyle='->'))
#ax1.annotate('',xy=(ini3,0.01),xytext=(ini3-0.05,0.01),arrowprops=dict(arrowstyle='->'))

ax1.annotate('',xy=(ini2,h2),xytext=(ini1,h1),arrowprops=dict(arrowstyle='->'))
ax1.annotate('',xy=(ini3,h3),xytext=(ini2,h2),arrowprops=dict(arrowstyle='->'))
ax1.annotate('',xy=(tgt,h3),xytext=(ini3,h3),arrowprops=dict(arrowstyle='->'))
#ax.plot([0.25,0.9],[0.01,0.01],ls=':',color='black')
#ax.scatter([0.5],[0.01],marker='x',color='red')
#ax1.annotate('Fail',xy=(0.5,0.01),xytext=(0.45,-0.03),arrowprops=dict(arrowstyle='->'))
#ax.scatter([0.15],[0.01],facecolor='none',edgecolor='blue')
#ax1.annotate('Success',xy=(0.15,0.01),xytext=(0.05,-0.03),arrowprops=dict(arrowstyle='->'))


ax1.vlines([0.3,0.7],0.005,-0.005,colors='black')
ax1.annotate(r'$f^L$',xy=(0.28,-0.02))
ax1.annotate(r'$f^U$',xy=(0.68,-0.02))

#ax1.legend(frameon=False,loc=(0,-0.1))
ax1.axis('off')

#Two strain case
#mid frequency
ax2=plt.axes((0.0,0.5,0.3,0.25))

#frame
#ax1.hlines(0,0,1,colors='black',lw=3)
ax2.annotate('',xy=(1,0),xytext=(0,0),arrowprops=dict(arrowstyle='->'))
#ax.fill_between([0.3,0.7],0.02,0,color='lightgray')
ax2.fill_between([0,1],0.02,0,color='red',alpha=0.3)
#ax1.fill_between([0.3,1],0.02,0,color='red',alpha=0.5)
#ax.annotate('Fail',xy=(0.45,0.005))
ax2.annotate(r'$0$',xy=(0,-0.02))
ax2.annotate(r'$1$',xy=(0.95,-0.02))
#ax2.annotate('Mutant\nfrequency',xy=(1.05,-0.005))
#ax2.annotate('(a) Two-strain',xy=(-0.2,0.95),xycoords='axes fraction')

ax2.set_ylim(ymin=-0.05,ymax=0.05)

tgt=0.5
ini1=0.2
h1=0.010
ini2=0.4
h2=0.01
ini3=0.8
h3=0.01
#ax2.scatter(tgt,0.015,c='black',marker='s') #target
ax2.vlines(tgt,0,0.02,colors='black',ls=':',label='Target') #target
#ax2.annotate('Target',xy=(tgt,0.015),xytext=(tgt-0.1,0.035),arrowprops=dict(arrowstyle='->'))
ax2.scatter(ini1,h1,c='black',marker='o',label='Initial(low)') #initial 1
#ax1.annotate('Initial',xy=(ini1,0.015),xytext=(ini1-0.05,0.03),arrowprops=dict(arrowstyle='->'))
ax2.scatter(ini2,h2,c='black',marker='o',label='Initial(mid)') #initial 2
#ax1.annotate('Initial',xy=(ini2,0.015),xytext=(ini2-0.05,0.03),arrowprops=dict(arrowstyle='->'))
ax2.scatter(ini3,h3,c='black',marker='o',label='Initial(high)') #initial 2
#ax1.annotate('Initial',xy=(ini3,0.015),xytext=(ini3-0.05,0.03),arrowprops=dict(arrowstyle='->'))
#ax1.annotate('',xy=(ini3,0.01),xytext=(ini3-0.05,0.01),arrowprops=dict(arrowstyle='->'))

ax2.annotate('',xy=(ini2,h2),xytext=(ini1,h1),arrowprops=dict(arrowstyle='->'))
ax2.annotate('',xy=(0.7,h2),xytext=(ini2,h2),arrowprops=dict(arrowstyle='->'))
ax2.annotate('',xy=(0.7,h3),xytext=(ini3,h3),arrowprops=dict(arrowstyle='->'))
#ax.plot([0.25,0.9],[0.01,0.01],ls=':',color='black')
#ax.scatter([0.5],[0.01],marker='x',color='red')
#ax1.annotate('Fail',xy=(0.5,0.01),xytext=(0.45,-0.03),arrowprops=dict(arrowstyle='->'))
#ax.scatter([0.15],[0.01],facecolor='none',edgecolor='blue')
#ax1.annotate('Success',xy=(0.15,0.01),xytext=(0.05,-0.03),arrowprops=dict(arrowstyle='->'))
#ax2.annotate('',xy=(0.7,h2),xytext=(tgt,h2),arrowprops=dict(arrowstyle='fancy'))

ax2.vlines([0.3,0.7],0.005,-0.005,colors='black')
ax2.annotate(r'$f^L$',xy=(0.28,-0.02))
ax2.annotate(r'$f^U$',xy=(0.68,-0.02))

#ax1.legend(frameon=False,loc=(0,-0.1))
ax2.axis('off')

#Two strain case
#small frequency
ax3=plt.axes((0.0,0.3,0.3,0.25))

#frame
#ax1.hlines(0,0,1,colors='black',lw=3)
ax3.annotate('',xy=(1,0),xytext=(0,0),arrowprops=dict(arrowstyle='->'))
#ax.fill_between([0.3,0.7],0.02,0,color='lightgray')
ax3.fill_between([0,0.3],0.025,0,color='green',alpha=0.3, label='success')
ax3.fill_between([0.3,1],0.025,0,color='red',alpha=0.3,label='fail')
#ax.annotate('Fail',xy=(0.45,0.005))
ax3.annotate(r'$0$',xy=(0,-0.02))
ax3.annotate(r'$1$',xy=(0.95,-0.02))
ax3.annotate('Mutant\nfrequency',xy=(0.8,-0.0),xycoords='axes fraction')
#ax2.annotate('(a) Two-strain',xy=(-0.2,0.95),xycoords='axes fraction')

ax3.set_ylim(ymin=-0.05,ymax=0.05)

tgt=0.05
ini1=0.2
h1=0.015
ini2=0.5
h2=0.015
ini3=0.8
h3=0.015
#ax3.scatter(tgt,0.015,c='black',marker='s') #target

#ax3.annotate('Target',xy=(tgt,0.015),xytext=(tgt-0.1,0.035),arrowprops=dict(arrowstyle='->'))
ax3.scatter(ini1,h1,c='black',marker='o',label='Initial') #initial 1
#ax1.annotate('Initial',xy=(ini1,0.015),xytext=(ini1-0.05,0.03),arrowprops=dict(arrowstyle='->'))
ax3.scatter(ini2,h2,c='black',marker='o') #initial 2
#ax1.annotate('Initial',xy=(ini2,0.015),xytext=(ini2-0.05,0.03),arrowprops=dict(arrowstyle='->'))
ax3.scatter(ini3,h3,c='black',marker='o') #initial 2
ax3.vlines(tgt,-0.005,0.025,colors='black',ls=':',label='Target') #target
#ax1.annotate('Initial',xy=(ini3,0.015),xytext=(ini3-0.05,0.03),arrowprops=dict(arrowstyle='->'))
#ax1.annotate('',xy=(ini3,0.01),xytext=(ini3-0.05,0.01),arrowprops=dict(arrowstyle='->'))

ax3.annotate('',xy=(tgt,h1),xytext=(ini1,h1),arrowprops=dict(arrowstyle='->'))
ax3.annotate('',xy=(0.7,h2),xytext=(ini2,h2),arrowprops=dict(arrowstyle='->'))
ax3.annotate('',xy=(0.7,h3),xytext=(ini3,h3),arrowprops=dict(arrowstyle='->'))
#ax.plot([0.25,0.9],[0.01,0.01],ls=':',color='black')
#ax.scatter([0.5],[0.01],marker='x',color='red')
#ax1.annotate('Fail',xy=(0.5,0.01),xytext=(0.45,-0.03),arrowprops=dict(arrowstyle='->'))
#ax.scatter([0.15],[0.01],facecolor='none',edgecolor='blue')
#ax1.annotate('Success',xy=(0.15,0.01),xytext=(0.05,-0.03),arrowprops=dict(arrowstyle='->'))
#ax3.annotate('',xy=(0.7,h2),xytext=(tgt,h2),arrowprops=dict(arrowstyle='fancy'))

ax3.vlines([0.3,0.7],0.005,-0.005,colors='black')
ax3.annotate(r'$f^L$',xy=(0.28,-0.02))
ax3.annotate(r'$f^U$',xy=(0.68,-0.02))

ax3.legend(frameon=False,loc=(0,-0.8))
ax3.axis('off')
# Out:
# (-0.05, 1.05, -0.05, 0.05)

# %%
############################################
# Schematic - maturation of three strain
############################################

cc=['#75140c','#0044aa','#a004bf']

#location fix
mxx=0
mxy=0.44
mx=plt.axes((mxx,mxy,0.4,0.4))
mx.annotate('a',xy=(-0,1.1),weight='bold',xycoords='axes fraction')
mx.annotate(' Expansion on three-strain system',xy=(0.05,1.1),xycoords='axes fraction')
def draw_birth(ax,x,y,ut='',dt='',c='r',scale=1):
    rad=0.4
    ax.add_patch(mpl.patches.Circle((x,y), radius=rad, color=c,ec='black'))
    ax.annotate('',xy=(x+3.5,y),xytext=(x+0.5,y),arrowprops=dict(arrowstyle='->'))
    ax.add_patch(mpl.patches.Circle((x+4,y), radius=rad, color=c,ec='black'))
    ax.add_patch(mpl.patches.Circle((x+5,y), radius=rad, color=c,ec='black'))
    ax.annotate(ut,xy=(x+2,y+0.1),ha='center',va='bottom')
    ax.annotate(dt,xy=(x+2,y-0.1),ha='center',va='top')
    return ax

def draw_mutation(ax,x,y,cl='r',cr='b',scale=1):
    rad=0.4
    ax.add_patch(mpl.patches.Circle((x,y), radius=rad, color=cl,ec='black'))
    ax.annotate('',xy=(x+3.5,y),xytext=(x+0.5,y),arrowprops=dict(arrowstyle='->'))
    ax.add_patch(mpl.patches.Circle((x+4,y), radius=rad, color=cr,ec='black'))
    ax.annotate(r'$\mu$',xy=(x+2,y+0.1),ha='center',va='bottom')
    return ax

rx1=0
ry1=0

draw_birth(mx,rx1,ry1,ut=r'$r$',c=cc[0])


ry2=-2
draw_birth(mx,rx1,ry2,ut=r'$r+s$',dt=r'$s>0$',c=cc[1])

ry3=-4
draw_birth(mx,rx1,ry3,ut=r'$r+2s$',dt=r'$s>0$',c=cc[2])

rx2=7
draw_mutation(mx,rx1,ry3-2,cl=cc[0],cr=cc[1])
draw_mutation(mx,rx1,ry3-4,cl=cc[1],cr=cc[2])

mx.axis('scaled')
mx.tick_params(left=False,bottom=False,labelleft=False,labelbottom=False)
mx.set_ylim(ymin=-10,ymax=2)

    

    

############################################
#prepare for triangle plot
############################################

x1=[0,1]
y1=[0,0]
x2=[0,0.5]
y2=[0,np.sqrt(3)*0.5]
x3=[0.5,1]
y3=[np.sqrt(3)*0.5,0]

cv1yl=0.05
cv1xl=cv1yl/np.sqrt(3)
cv1yr=0.25
cv1xr=1-cv1yr/np.sqrt(3)

def curve1(x,a,b):
	return a*x**2+b
def curve1p(x,x1,y1,x2,y2):
	return (y2-y1)/(x2-x1)**4*(x-x1)**4+y1

a1=(cv1yl-cv1yr)/(cv1xl**2-cv1xr**2)
b1=(-cv1xr**2*cv1yl+cv1xl**2*cv1yr)/(cv1xl**2-cv1xr**2)

cv1x=np.arange(cv1xl,cv1xr+0.005,0.01)
cv1y=curve1p(cv1x,cv1xl,cv1yl,cv1xr,cv1yr)

cv2yl=0.61
cv2xl=cv2yl/np.sqrt(3)
cv2yr=0.6
cv2xr=1-cv2yr/np.sqrt(3)

def curve2(x,a,b,c):
	return a*(x-c)**2+b

c=0.51
a2=(cv2yl-cv2yr)/((cv2xl-c)**2-(cv2xr-c)**2)
b2=(-(cv2xr-c)**2*cv2yl+(cv2xl-c)**2*cv2yr)/((cv2xl-c)**2-(cv2xr-c)**2)

cv2x=np.arange(cv2xl,cv2xr+0.005,0.01)
cv2y=curve2(cv2x,a2,b2,c)

#low region1
xl1=np.linspace(0,cv1xl)
yl1=np.sqrt(3)*xl1

#low region2
xl2=np.linspace(cv1xl,cv1xr)
#yl2=curve1(xl2,a1,b1)
yl2=curve1p(xl2,cv1xl,cv1yl,cv1xr,cv1yr)

#low region3
xl3=np.linspace(cv1xr,1)
yl3=-np.sqrt(3)*(xl3-1)


#high region1
xh1=np.linspace(cv2xl,0.5)
yh1u=np.sqrt(3)*xh1
yh1d=curve2(xh1,a2,b2,c)


#high region1
xh2=np.linspace(0.5,cv2xr)
yh2u=-np.sqrt(3)*(xh2-1)
yh2d=curve2(xh2,a2,b2,c)

#point initial and target
i1x=0.5
i1y=0.75
i2x=0.05
i2y=0.03

i3x=0.3
i3y=0.00


#three strain explanation
bxx=0.45
bxy=0.45

bx=plt.axes((bxx+1.,bxy,0.35,0.35))
bx.annotate('b',xy=(-0.1,1.1),weight='bold',xycoords='axes fraction')
bx.annotate(' Artificial-selection-dominant region',xy=(-0.05,1.1),xycoords='axes fraction')
#bx.annotate('Wildtype\nfrequency(W)',xy=(0,-0.1),xycoords='axes fraction',ha='center',va='center')
#bx.annotate('Single-mutant\nfrequency(S)',xy=(0.95,-0.1),xycoords='axes Fraction',ha='center',va='center')
#bx.annotate('Double-mutant\nfrequency(D)',xy=(0.5,1.1),xycoords='axes fraction',ha='center',va='center')
bx.add_patch(mpl.patches.Circle((-0.15,-0.15), radius=0.1, color=cc[0],ec='black'))
bx.add_patch(mpl.patches.Circle((1.15,-0.15), radius=0.1, color=cc[1],ec='black'))
bx.add_patch(mpl.patches.Circle((0.5,1.1), radius=0.1, color=cc[2],ec='black'))
bx.plot(x1,y1,c='black')
bx.plot(x2,y2,c='black')
bx.plot(x3,y3,c='black')


bx.fill_between(xl1,yl1,0,color='lightgray')
bx.fill_between(xl2,yl2,0,color='lightgray')
bx.fill_between(xl3,yl3,0,color='lightgray')
bx.fill_between(xh1,yh1u,yh1d,color='lightgray')
bx.fill_between(xh2,yh2u,yh2d,color='lightgray',label='AS-dominant')
bx.text(
    -0.5, 0.5, "   ", ha="right", va="center", rotation=0, size=20,
    bbox=dict(boxstyle="rarrow,pad=0.3", fc='w',lw=3))

bx.axis('scaled')
bx.axis('off')


bx0=plt.axes((bxx+0.35,bxy+0.07,0.20,0.20))
bx0.set_xlim(xmin=-1,xmax=1)
bx0.set_ylim(ymin=-1,ymax=1)
bx0.annotate(r'$\Delta f$',xy=(-1,0),xytext=(1,0),arrowprops=dict(arrowstyle='<-'),ha='left',va='center')
bx0.annotate(r'$\Delta h$',xy=(0,-1),xytext=(0,1),arrowprops=dict(arrowstyle='<-'),ha='center',va='bottom')
bx0.scatter(0.,0.)
#bx0.annotate('Selecteed',xy=(0.6,0.6))
#bx0.fill_between([-1,0],[-2,-2],color='lightgray')
#bx0.annotate('AS-dom.',xy=(-0.5,-0.5),ha='center',va='center')
bx0.scatter(0.5,0.5)
bx0.annotate('',xy=(0.5,0.5),xytext=(0.0,0.0),arrowprops=dict(arrowstyle='->'))
bx0.annotate('(I)',xy=(0.7,0.5),ha='center',va='center')
bx0.annotate('',xy=(-0.5,0.5),xytext=(0.0,0.0),arrowprops=dict(arrowstyle='->'))
bx0.annotate('(II)',xy=(-0.7,0.5),ha='center',va='center')
bx0.scatter(-0.5,0.5)
bx0.annotate('Maturation',xy=(0.5,1.2),xycoords='axes fraction',ha='center',va='center')
bx0.annotate('',xy=(1.5,0.8),xytext=(1.2,0.6),xycoords='axes fraction',arrowprops=dict(arrowstyle='->'))
bx0.annotate('',xy=(1.5,0.2),xytext=(1.2,0.4),xycoords='axes fraction',arrowprops=dict(arrowstyle='->'))
bx0.axis('off')


bx1=plt.axes((bxx+0.7,bxy+0.15,0.20,0.20))
bx1.set_xlim(xmin=-1,xmax=1)
bx1.set_ylim(ymin=-1,ymax=1)
bx1.annotate(r'$\Delta f$',xy=(-1,0),xytext=(1,0),arrowprops=dict(arrowstyle='<-'),ha='left',va='center')
bx1.annotate(r'$\Delta h$',xy=(0,-1),xytext=(0,1),arrowprops=dict(arrowstyle='<-'),ha='center',va='bottom')
bx1.scatter(0.5,0.5)
#bx1.annotate('Maturation',xy=(0.6,0.6))
bx1.fill_between([-1,0],[-2,-2],color='lightgray')
#bx1.annotate('AS-dom.',xy=(-0.5,-0.5),ha='center',va='center')
bx1.text(
    0, 0, "Selection", ha="center", va="center", rotation=45, size=9,
    bbox=dict(boxstyle="larrow,pad=0.3", fc='w',lw=1))
bx1.axis('off')

bx2=plt.axes((bxx+0.7,bxy-0.1,0.20,0.20))
bx2.set_xlim(xmin=-1,xmax=1)
bx2.set_ylim(ymin=-1,ymax=1)
bx2.annotate(r'$\Delta f$',xy=(-1,0),xytext=(1,0),arrowprops=dict(arrowstyle='<-'),ha='left',va='center')
bx2.annotate(r'$\Delta h$',xy=(0,-1),xytext=(0,1),arrowprops=dict(arrowstyle='<-'),ha='center',va='bottom')
bx2.scatter(-0.5,0.5)
bx2.fill_between([0,1],[-2,-2],color='lightgray')
bx2.text(
    0, 0, "Selection", ha="center", va="center", rotation=-45, size=9,
    bbox=dict(boxstyle="rarrow,pad=0.3", fc='w',lw=1))
#bx2.annotate('AS-dom.',xy=(0.5,-0.5),ha='center',va='center')
bx2.axis('off')

#Three strain case
cxx=-0.1
cxy=-0.2

cx=plt.axes((cxx,cxy,0.35,0.35))
cx.annotate('c',xy=(-0.0,1.0),weight='bold',xycoords='axes fraction')
cx.annotate(' Composition trajectories according to the target compositions',xy=(0.05,1.0),xycoords='axes fraction')
#cx.annotate('high D',xy=(0,1.15),xycoords='axes fraction')
cx.plot(x1,y1,c='black')
cx.plot(x2,y2,c='black')
cx.plot(x3,y3,c='black')
#cx.annotate('W',xy=(0,-0.05),xycoords='axes fraction')
#cx.annotate('S',xy=(0.95,-0.05),xycoords='axes fraction')
#cx.annotate('D',xy=(0.5,1.02),xycoords='axes fraction')
cx.add_patch(mpl.patches.Circle((-0.10,-0.10), radius=0.07, color=cc[0],ec='black'))
cx.add_patch(mpl.patches.Circle((1.10,-0.10), radius=0.07, color=cc[1],ec='black'))
cx.add_patch(mpl.patches.Circle((0.5,1.00), radius=0.07, color=cc[2],ec='black'))


cx.fill_between(xl1,yl1,0,color='lightgray')
cx.fill_between(xl2,yl2,0,color='lightgray')
cx.fill_between(xl3,yl3,0,color='lightgray')
cx.fill_between(xh1,yh1u,yh1d,color='lightgray')
cx.fill_between(xh2,yh2u,yh2d,color='lightgray')#,label='Artificial-selection-dominant')

cx.scatter(i1x,i1y,color='black',label='Initial')
cx.scatter(i2x,i2y,color='black')
cx.scatter(i3x,i3y,color='black')
fx=0.4
fy=np.sqrt(3)*0.37
cx.scatter(fx,fy,marker='s',color='black',label='Target')

cx.annotate('',xy=(fx,fy),xytext=(i1x,i1y),arrowprops=dict(arrowstyle='->',color='green'))
cx.annotate('',xy=(fx,fy),xytext=(i2x,i2y),arrowprops=dict(arrowstyle='->',color='green'))
cx.annotate('',xy=(fx,fy),xytext=(i3x,i3y),arrowprops=dict(arrowstyle='->',color='green'))
cx.legend(frameon=False,loc=(0,-0.2))
cx.axis('scaled')
cx.axis('off')


#second plot
cx2=plt.axes((cxx+0.45,cxy,0.35,0.35))
cx2.plot(x1,y1,c='black')
cx2.plot(x2,y2,c='black')
cx2.plot(x3,y3,c='black')
#cx2.annotate('W',xy=(0,-0.05),xycoords='axes fraction')
#cx2.annotate('S',xy=(0.95,-0.05),xycoords='axes fraction')
#cx2.annotate('D',xy=(0.5,1.02),xycoords='axes fraction')
#cx2.annotate('Medium D',xy=(0,1.15),xycoords='axes fraction')
cx2.add_patch(mpl.patches.Circle((-0.10,-0.10), radius=0.07, color=cc[0],ec='black'))
cx2.add_patch(mpl.patches.Circle((1.10,-0.10), radius=0.07, color=cc[1],ec='black'))
cx2.add_patch(mpl.patches.Circle((0.5,1.00), radius=0.07, color=cc[2],ec='black'))

#low region1
cx2.fill_between(xl1,yl1,0,color='lightgray')

#low region2
cx2.fill_between(xl2,yl2,0,color='lightgray')

#low region3
cx2.fill_between(xl3,yl3,0,color='lightgray')

#high region1
cx2.fill_between(xh1,yh1u,yh1d,color='lightgray')

#high region1
cx2.fill_between(xh2,yh2u,yh2d,color='lightgray')#,label='Artificial\n-selection\n-dominant')


cx2.scatter(i1x,i1y,color='black',label='Initial')
cx2.scatter(i2x,i2y,color='black')
cx2.scatter(i3x,i3y,color='black')
fx=0.5
fy=np.sqrt(3)*0.2
cx2.scatter(fx,fy,marker='s',color='black',label='Target')
#cx2.annotate('Target',xy=(fx,fy),xytext=(fx+0.1,fy-0.1),arrowprops=dict(arrowstyle='->'))
cx2.annotate('',xy=(cv2xr,cv2yr),xytext=(i1x,i1y),arrowprops=dict(arrowstyle='->',color='red'))
cx2.annotate('',xy=(cv2xr,cv2yr),xytext=(i2x,i2y),arrowprops=dict(arrowstyle='->',color='red'))
#cx2.annotate('',xy=(cv2xr,cv2yr),xytext=(fx,fy+0.05),arrowprops=dict(arrowstyle='->'))
cx2.annotate('',xy=(cv2xr,cv2yr),xytext=(i3x,i3y),arrowprops=dict(arrowstyle='->',color='red'))
#cx2.annotate('',xy=(cv2xr,cv2yr),xytext=(fx,fy),arrowprops=dict(arrowstyle='fancy'))
cx2.axis('scaled')
cx2.axis('off')




cx3=plt.axes((cxx+0.9,cxy,0.35,0.35))
#cx3.annotate('W',xy=(0,-0.05),xycoords='axes fraction')
#cx3.annotate('S',xy=(0.95,-0.05),xycoords='axes fraction')
#cx3.annotate('D',xy=(0.5,1.02),xycoords='axes fraction')
#cx3.annotate('Low D',xy=(0,1.15),xycoords='axes fraction')
cx3.add_patch(mpl.patches.Circle((-0.10,-0.10), radius=0.07, color=cc[0],ec='black'))
cx3.add_patch(mpl.patches.Circle((1.10,-0.10), radius=0.07, color=cc[1],ec='black'))
cx3.add_patch(mpl.patches.Circle((0.5,1.00), radius=0.07, color=cc[2],ec='black'))

cx3.plot(x1,y1,c='black')
cx3.plot(x2,y2,c='black')
cx3.plot(x3,y3,c='black')


cx3.fill_between(xl1,yl1,0,color='lightgray')
cx3.fill_between(xl2,yl2,0,color='lightgray')
cx3.fill_between(xl3,yl3,0,color='lightgray')
cx3.fill_between(xh1,yh1u,yh1d,color='lightgray')
cx3.fill_between(xh2,yh2u,yh2d,color='lightgray',label='AS-dominant')



cx3.scatter(i1x,i1y,color='black',label='Initial 1')
cx3.scatter(i2x,i2y,color='black')
cx3.scatter(i3x,i3y,color='black')
fx=0.85
fy=0.15
cx3.scatter(fx,fy,marker='s',color='black',label='Target')

cx3.annotate('',xy=(cv2xr,cv2yr),xytext=(i1x,i1y),arrowprops=dict(arrowstyle='->',color='red'))
cx3.annotate('',xy=(cv1xr,cv1yr),xytext=(i2x,i2y),arrowprops=dict(arrowstyle='->',color='red'))
cx3.annotate('',xy=(fx,fy),xytext=(i3x,i3y),arrowprops=dict(arrowstyle='->',color='green'))

cx3.axis('scaled')
cx3.axis('off')

formatter='svg'
plt.savefig('Fig6_v2.'+formatter,dpi=300,bbox_inches='tight',format=formatter)

plt.show()
